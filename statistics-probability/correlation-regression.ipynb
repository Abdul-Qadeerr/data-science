# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-Qadeerr/data-science/blob/main/statistics-probability/correlation-regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Correlation & Simple Regression
# Correlation matrix and Linear Regression in DS context

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# Sample dataset
data = {
    'Age': [22, 25, 30, 35, 40, 45, 50, 55],
    'Salary': [25000, 28000, 35000, 40000, 45000, 50000, 60000, 65000]
}
df = pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   22   25000
# 1   25   28000
# 2   30   35000
# 3   35   40000
# 4   40   45000
# 5   45   50000
# 6   50   60000
# 7   55   65000

# %%
# Correlation
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Simple Linear Regression
X = df[['Age']]
y = df['Salary']

model = LinearRegression()
model.fit(X, y)

print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])
# Out:
# Intercept: -2099.3899339095005
# Coefficient: 1207.9308591764106

# %%
# Plot regression line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.show()
